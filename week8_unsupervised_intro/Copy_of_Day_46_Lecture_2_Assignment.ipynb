# %% [markdown]
# ## Day 46 Lecture 2 Assignment
#
# In this assignment, we will calculate a similarity matrix using responses to a survey about student life at a university. We will perform clustering on this dataset later on.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# This dataset consists of 35 binary features, each corresponding to a yes/no question that characterizes the student taking the survey.
#
# This dataset contains a large number of features, each corresponding to a survey question. The feature name summarizes the survey question, so we will not list them all out here.
#
# Load the dataset.

# %%
# answer goes here

student_life = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/student_life_survey.csv')

# %%
student_life.head()
# Out:
#    Q2-Participated in Societies and Interest Groups  ...  response_id
# 0                                                 0  ...            1
# 1                                                 0  ...            2
# 2                                                 0  ...            3
# 3                                                 1  ...            4
# 4                                                 1  ...            5
#
# [5 rows x 36 columns]

# %% [markdown]
# For our analysis, we will focus on a specific subset of the survey that is focused on stress. These questions all begin with the string 'Q5'. Filter the columns that meet this criteria (should be 10 in total).

# %%
# answer goes here

stress= student_life.filter(regex='Q5')
stress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2958 entries, 0 to 2957
# Data columns (total 10 columns):
# Q5-Stressed about Adjustment issues                                                    2958 non-null int64
# Q5-Stressed about Academic issues                                                      2958 non-null int64
# Q5-Stressed about Financial issues                                                     2958 non-null int64
# Q5-Stressed about Family issues                                                        2958 non-null int64
# Q5-Stressed about Friendships                                                          2958 non-null int64
# Q5-Stressed about Romantic relationships                                               2958 non-null int64
# Q5-Stressed about  Health related issues                                               2958 non-null int64
# Q5-Stressed about Career related issues                                                2958 non-null int64
# Q5-Stressed about My involvement in hostel, clubs, societies, interest groups, etc.    2958 non-null int64
# Q5-Stressed about Others                                                               2958 non-null int64
# dtypes: int64(10)
# memory usage: 231.2 KB

# %% [markdown]
# We'll assume for the next step that a pair of negative values (i.e. both responses are "no") is as informative as a pair of positive values. Compute the full distance/dissimilarity matrix for the survey data using matching/hamming distance.
#
# The pdist function is a simple way to accomplish this goal, and the squareform function will transform the output of the pdist function into a tabular format that can be convert to a dataframe more easily.

# %%
# answer goes here


pdist_array=pdist(stress, metric='hamming')
pdist_tabular= squareform(pdist_array)

# %%
pdist_df= pd.DataFrame(data=pdist_tabular)
pdist_df
# Out:
#       0     1     2     3     4     5     ...  2952  2953  2954  2955  2956  2957
# 0      0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   0.0   0.0   0.2   0.2
# 1      0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   0.0   0.0   0.2   0.2
# 2      0.1   0.1   0.0   0.7   0.4   0.2  ...   0.4   0.3   0.1   0.1   0.1   0.1
# 3      0.6   0.6   0.7   0.0   0.5   0.5  ...   0.3   0.6   0.6   0.6   0.6   0.8
# 4      0.3   0.3   0.4   0.5   0.0   0.2  ...   0.2   0.3   0.3   0.3   0.5   0.3
# ...    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 2953   0.2   0.2   0.3   0.6   0.3   0.3  ...   0.5   0.0   0.2   0.2   0.4   0.2
# 2954   0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   0.0   0.0   0.2   0.2
# 2955   0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   0.0   0.0   0.2   0.2
# 2956   0.2   0.2   0.1   0.6   0.5   0.3  ...   0.5   0.4   0.2   0.2   0.0   0.2
# 2957   0.2   0.2   0.1   0.8   0.3   0.3  ...   0.5   0.2   0.2   0.2   0.2   0.0
#
# [2958 rows x 2958 columns]

# %% [markdown]
# Print the answers to the following three questions:
#
# 1. How many pairs of students are there in our dataset? (Remember to ignore a student pairing with themselves, and avoid double-counting - '3-5' is the same as '5-3'.)
# 2. Of these pairs, how many gave identical answers?
# 3. How many pairs had no answers in common?
#
# Tip: it may help to first convert the NxN similarity matrix into a table with three columns: response_id_1, response_id_2, and the similarity between them. The new table should have NxN rows and 3 columns.

# %%
# answer goes here
# Create a mask that masks the top right triangle (nulls where index and column are identical and where repeats exist)
mask = np.triu(np.ones_like(pdist_df, dtype=np.bool))

# Count all unique pairs (making nonunique pairs nulls using a triu)
print('Number of unique pairs:', pdist_df.mask(mask).count().sum())
# Out:
# Number of unique pairs: 4373403

# %%
# create a new df
pdist_unique= pdist_df.mask(mask)

# %%
# check out new df 
pdist_unique
# Out:
#       0     1     2     3     4     5     ...  2952  2953  2954  2955  2956  2957
# 0      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1      0.0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2      0.1   0.1   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3      0.6   0.6   0.7   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4      0.3   0.3   0.4   0.5   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 2953   0.2   0.2   0.3   0.6   0.3   0.3  ...   0.5   NaN   NaN   NaN   NaN   NaN
# 2954   0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   NaN   NaN   NaN   NaN
# 2955   0.0   0.0   0.1   0.6   0.3   0.1  ...   0.3   0.2   0.0   NaN   NaN   NaN
# 2956   0.2   0.2   0.1   0.6   0.5   0.3  ...   0.5   0.4   0.2   0.2   NaN   NaN
# 2957   0.2   0.2   0.1   0.8   0.3   0.3  ...   0.5   0.2   0.2   0.2   0.2   NaN
#
# [2958 rows x 2958 columns]

# %%
# count total number of 0s to find identical answers 
pdist_unique.isin([0]).sum().sum()
# Out:
# 136733

# %%
# count total number of 1s to find identical answers 
pdist_unique.isin([1]).sum().sum()
# Out:
# 291

# %% [markdown]
# For each student, calculate their average similarity with all other students. Then print the following:
#
# 1. On average, which student (i.e. which response_id) had the most similar responses to the survey population as a whole? What was the average similarity for this student, and what were their answers?
# 2. Repeat part 1, but for the student with the least similar responses to the survey population as a whole.
# 3. What do we notice about these students? What broader inferences can we make about the student population as a whole?

# %%
# answer goes here

pdist_df['average'] = pdist_df.mean(axis=0)

# %%
pdist_df.sort_values('average')
# Out:
#         0    1    2    3    4    5  ...  2953  2954  2955  2956  2957   average
# 0     0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
# 440   0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
# 1865  0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
# 1869  0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
# 433   0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
# ...   ...  ...  ...  ...  ...  ...  ...   ...   ...   ...   ...   ...       ...
# 866   0.8  0.8  0.7  0.2  0.5  0.7  ...   0.6   0.8   0.8   0.6   0.6  0.593577
# 878   0.8  0.8  0.7  0.2  0.5  0.7  ...   0.6   0.8   0.8   0.6   0.6  0.593577
# 1796  0.8  0.8  0.7  0.2  0.5  0.7  ...   0.6   0.8   0.8   0.6   0.6  0.593577
# 2416  0.7  0.7  0.6  0.3  0.6  0.6  ...   0.9   0.7   0.7   0.5   0.7  0.601149
# 2899  0.8  0.8  0.7  0.4  0.5  0.7  ...   0.8   0.8   0.8   0.6   0.6  0.623935
#
# [2958 rows x 2959 columns]

# %%
print('The student with the most similar responses to the survey population as a whole is: student 0')
print('The average similarity for this student is:', pdist_df['average'].iloc[0])
print('The answers for their questions are:', pdist_df.loc[[0]])
# Out:
# The student with the most similar responses to the survey population as a whole is: student 0
# The average similarity for this student is: 0.224746450304262
# The answers for their questions are:      0    1    2    3    4    5  ...  2953  2954  2955  2956  2957   average
# 0  0.0  0.0  0.1  0.6  0.3  0.1  ...   0.2   0.0   0.0   0.2   0.2  0.224746
#
# [1 rows x 2959 columns]

# %%
print('The student with the least similar responses to the survey population as a whole is: student 2899')
print('The average similarity for this student is:', pdist_df['average'].iloc[2899])
print('The answers for their questions are:', pdist_df.loc[[2899]])
# Out:
# The student with the least similar responses to the survey population as a whole is: student 2899
# The average similarity for this student is: 0.6239350912778868
# The answers for their questions are:         0    1    2    3    4    5  ...  2953  2954  2955  2956  2957   average
# 2899  0.8  0.8  0.7  0.4  0.5  0.7  ...   0.8   0.8   0.8   0.6   0.6  0.623935
#
# [1 rows x 2959 columns]

# %% [markdown]
# Create recommended df for reference.

# %%
# create a pairwise distance matrix
pairwise = pd.DataFrame(
    squareform(pdist(stress, metric='hamming')),
    columns = stress.index,
    index = stress.index
)

# Create a mask that masks the top right triangle (nulls where index and column are identical and where repeats exist)
mask = np.triu(np.ones_like(pairwise, dtype=np.bool))

# create a new df
pairwise= pairwise.mask(mask)

# move to long form
long_form = pairwise.unstack()

# rename columns and turn into a dataframe
long_form.index.rename(['response_id_1', 'response_id_2'], inplace=True)
long_form = long_form.to_frame('hamming dissim').reset_index()
long_form.dropna(inplace=True)

# %%
long_form
# Out:
#          response_id_1  response_id_2  hamming dissim
# 1                    0              1             0.0
# 2                    0              2             0.1
# 3                    0              3             0.6
# 4                    0              4             0.3
# 5                    0              5             0.1
# ...                ...            ...             ...
# 8740888           2954           2956             0.2
# 8740889           2954           2957             0.2
# 8743846           2955           2956             0.2
# 8743847           2955           2957             0.2
# 8746805           2956           2957             0.2
#
# [4373403 rows x 3 columns]
