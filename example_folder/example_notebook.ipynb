# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(columns=['A', 'B', 'C'])

for col in df.columns:
    df[col] = np.random.normal(size=10000)

df['D'] = df['A'] * df['B']

df.head()
# Out:
#           A         B         C         D
# 0 -0.091582  1.439768  1.252727 -0.131857
# 1  0.998169 -1.072746 -1.027143 -1.070781
# 2  0.460854 -1.339368  0.697827 -0.617253
# 3 -0.263776  0.497773  0.098206 -0.131301
# 4  1.297913  0.823746 -1.578985  1.069150

# %%
plt.hist(df['A'], bins=50)
plt.show()

# %%
plt.scatter(df['A'], df['D'], c=df['B'])
plt.xlabel('A')
plt.ylabel('D')
plt.title('B')
plt.colorbar()
plt.show()
